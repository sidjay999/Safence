# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")
# Out:
# True
# NVIDIA A100 80GB PCIe

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")#nano yolov8 model

model.train(
    data="/home/user02/Documents/fences/electric_fences/data.yaml",
    epochs=50,
    imgsz=416,
    batch=4,
    device=0 
)
# Out:
# Ultralytics 8.3.199 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100 80GB PCIe, 81153MiB)
# ...

# %%
import os
model = YOLO("/home/user02/Documents/fences/electric_fences/runs/detect/train4/weights/best.pt")
results = model("/home/user02/Documents/fences/electric_fences/test/images")
for r in results:
    r.show()#display window
    out_path = f"/home/user02/Documents/fences/electric_fences/preds/{os.path.basename(r.path)}"
    r.save(filename=out_path)
# Out:
# image 1/11 /home/user02/Documents/fences/electric_fences/test/images/fence_002_jpg.rf.6829d6c265755c2e5c2f64a13dd29ead.jpg: 416x416 1 fence, 18.0ms
# image 2/11 /home/user02/Documents/fences/electric_fences/test/images/fence_004_jpg.rf.5a73206c83434fe11ecad327fc20060c.jpg: 416x416 3 fences, 10.5ms
# image 3/11 /home/user02/Documents/fences/electric_fences/test/images/fence_007_jpg.rf.3ccb25d43b769e33a2533ae568fc594c.jpg: 416x416 1 fence, 10.6ms
# image 4/11 /home/user02/Documents/fences/electric_fences/test/images/fence_023_jpg.rf.776bd793679a3cd738c436833036cafc.jpg: 416x416 1 fence, 8.7ms
# image 5/11 /home/user02/Documents/fences/electric_fences/test/images/fence_024_jpg.rf.bae4439dc505c3618f4807a74a0e27da.jpg: 416x416 1 fence, 9.2ms
# image 6/11 /home/user02/Documents/fences/electric_fences/test/images/fence_033_jpg.rf.c12f084e1a62af488414eadca1f9caca.jpg: 416x416 1 fence, 16.5ms
# ...

# %%
metrics = model.val(data="/home/user02/Documents/fences/electric_fences/data.yaml",
                    split='test', 
                    device=0)  
print(metrics)
# Out:
# Ultralytics 8.3.199 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100 80GB PCIe, 81153MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 947.9±103.0 MB/s, size: 77.1 KB)
# val: Scanning /home/user02/Documents/fences/electric_fences/test/labels.cache... 11 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 11/11 7.8Kit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all         11         17      0.708      0.588      0.591      0.301
# Speed: 0.1ms preprocess, 3.5ms inference, 0.0ms loss, 4.4ms postprocess per image
# Results saved to /home/user02/Documents/fences/electric_fences/runs/detect/val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7fe20372dd80>
# ...
